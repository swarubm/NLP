# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/NLP/blob/main/44visualizing%20word%202%20vec%20gensim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Importing the Libraries

# %%
import matplotlib.pyplot as plt

from gensim.models import Word2Vec

from sklearn.decomposition import PCA

# %%
## Loading the Corpus

# %%
sentences = [['human', 'interface', 'computer'],
            ['survey', 'user', 'computer', 'system', 'response', 'time'],
            ['eps', 'user', 'interface', 'system'],
            ['system', 'human', 'system', 'eps'],
            ['user', 'response', 'time'],
            ['trees'],
            ['graph', 'trees'],
            ['graph', 'minors', 'trees'],
            ['graph', 'minors', 'survey']]

# %%
## Training the Word2Vec

# %%
model = Word2Vec(sentences = sentences, min_count = 1, vector_size = 10)

# %%
#Performing PCA

# %%
vectors = [model.wv[word] for word in model.wv.index_to_key]

pca = PCA(n_components = 2)
final_vec = pca.fit_transform(vectors)

# %%
## Visualising the Word Vectors

# %%
plt.scatter(final_vec[:,0], final_vec[:,1])
words = model.wv.index_to_key

for i, word in enumerate(words):
  plt.annotate(word, xy = (final_vec[i][0], final_vec[i][1]))
plt.show()
