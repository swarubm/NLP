# %%
sentence = " An AI engineer is a technology professional who designs, builds, and optimizes systems powered by artificial intelligence. Their role blends computer science, mathematics, and domain expertise to create models that can learn from data and make predictions or decisions. They often work with machine learning algorithms, natural language processing, and neural networks, applying these tools to solve real-world problems such as automating tasks, improving user experiences, or enabling smarter decision-making in industries like healthcare, finance, and robotics. Beyond technical skills, AI engineers also focus on scalability, ethical considerations, and deployment, ensuring that AI solutions are both effective and responsible in practice."

# %%
sentence.lower()
# Out:
# ' an ai engineer is a technology professional who designs, builds, and optimizes systems powered by artificial intelligence. their role blends computer science, mathematics, and domain expertise to create models that can learn from data and make predictions or decisions. they often work with machine learning algorithms, natural language processing, and neural networks, applying these tools to solve real-world problems such as automating tasks, improving user experiences, or enabling smarter decision-making in industries like healthcare, finance, and robotics. beyond technical skills, ai engineers also focus on scalability, ethical considerations, and deployment, ensuring that ai solutions are both effective and responsible in practice.'
