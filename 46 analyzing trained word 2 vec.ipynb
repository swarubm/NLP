# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/NLP/blob/main/46%20analyzing%20trained%20word%202%20vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gensim.downloader as api
from gensim.models import Word2Vec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1427/1116830432.py in <cell line: 0>()
# ----> 1 import gensim.downloader as api
#       2 from gensim.models import Word2Vec
#
# ModuleNotFoundError: No module named 'gensim'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# print(api.info()['corpora'])

corpus = api.load('text8')
corpus = [word  for word in corpus]

corpora = ''
for corp in corpus:
  corpora += ' '.join(corp)

print('Corpus Size : ' , len(corpora.split(' ')))
print('Vocab Size  : ' , len(set(corpora.split(' '))))

del corpora

model = Word2Vec( corpus, min_count = 5, vector_size = 300, window = 3, sg = 0, epochs = 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/176280673.py in <cell line: 0>()
#       1 # print(api.info()['corpora'])
#       2
# ----> 3 corpus = api.load('text8')
#       4 corpus = [word  for word in corpus]
#       5
#
# NameError: name 'api' is not defined

# %%
model.wv.most_similar('first', topn = 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/3268769939.py in <cell line: 0>()
# ----> 1 model.wv.most_similar('first', topn = 3)
#
# NameError: name 'model' is not defined

# %%
model.wv.most_similar('car', topn = 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/3489604423.py in <cell line: 0>()
# ----> 1 model.wv.most_similar('car', topn = 3)
#
# NameError: name 'model' is not defined

# %%
model.wv.most_similar('india', topn = 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/642933055.py in <cell line: 0>()
# ----> 1 model.wv.most_similar('india', topn = 10)
#
# NameError: name 'model' is not defined

# %%
model.wv.most_similar('mumbai', topn = 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/3893120522.py in <cell line: 0>()
# ----> 1 model.wv.most_similar('mumbai', topn = 10)
#
# NameError: name 'model' is not defined

# %%
model.wv['car']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/3629068038.py in <cell line: 0>()
# ----> 1 model.wv['car']
#
# NameError: name 'model' is not defined

# %%
model.wv.similarity('car','truck')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/1601306983.py in <cell line: 0>()
# ----> 1 model.wv.similarity('car','truck')
#
# NameError: name 'model' is not defined

# %%
model.wv.similarity('good','bad')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/924538554.py in <cell line: 0>()
# ----> 1 model.wv.similarity('good','bad')
#
# NameError: name 'model' is not defined

# %%
model.wv.similarity('best','better')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1427/527364964.py in <cell line: 0>()
# ----> 1 model.wv.similarity('best','better')
#
# NameError: name 'model' is not defined
