# %%
txt = "the number is 4578935 not 13408090"
for i in range(len(txt)):
    print(txt[i],txt[i].isdigit())
# Out:
# t False
# h False
# e False
#   False
# n False
# u False
# m False
# b False
# e False
# r False
#   False
# i False
# s False
#   False
# 4 True
# 5 True
# 7 True
# 8 True
# 9 True
# 3 True
# 5 True
#   False
# n False
# o False
# t False
#   False
# 1 True
# 3 True
# 4 True
# 0 True
# 8 True
# 0 True
# 9 True
# 0 True

# %%
for i in range(len(txt)):
    if(txt[i].isdigit()==True):
        print(txt[i])
# Out:
# 4
# 5
# 7
# 8
# 9
# 3
# 5
# 1
# 3
# 4
# 0
# 8
# 0
# 9
# 0

# %%
for i in range(len(txt)):
    if(txt[i].isdigit()==True):
        c+=1
        print(txt[i],c)
    else:
        c=0
# Out:
# 4 1
# 5 2
# 7 3
# 8 4
# 9 5
# 3 6
# 5 7
# 1 1
# 3 2
# 4 3
# 0 4
# 8 5
# 0 6
# 9 7
# 0 8

# %%
for i in range(len(txt)):
    if(txt[i].isdigit()==True):
        c+=1
        print(txt[i],c,i) #with index
    else:
        c=0
# Out:
# 4 1 14
# 5 2 15
# 7 3 16
# 8 4 17
# 9 5 18
# 3 6 19
# 5 7 20
# 1 1 26
# 3 2 27
# 4 3 28
# 0 4 29
# 8 5 30
# 0 6 31
# 9 7 32
# 0 8 33

# %% [markdown]
# ## continuous numbers

# %%
txt = 'The number is 8372493 not 423423.'

c = 0

for i in range(len(txt)):
    if (txt[i].isdigit() == True):        # If Digit
        if (c == 0):                      # Count Number of Digits
            st = i                        # Starting the Number
        c += 1                            # Incrementing the Counter for that number
    else:                                 # If not Digit
        if (c != 0):                      # If coming from a digit
            end =  i                      # Ending the Number
            print(txt[st:end])            # Printing the Number
        c = 0                             
        
if (c != 0):                              # If Number is at the end of the string
    print(txt[-c:])
# Out:
# 8372493
# 423423
