# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/NLP/blob/main/44%20training%20%20word%202%20vec%20corpus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gensim.downloader as api
from gensim.models import Word2Vec

# %%
# !pip install gensim
import gensim.downloader as api
from gensim.models import Word2Vec

# print(api.info()['corpora'])

corpus = api.load('text8')
corpus = [word  for word in corpus]

corpora = ''
for corp in corpus:
  corpora += ' '.join(corp)

print('Corpus Size : ' , len(corpora.split(' ')))
print('Vocab Size  : ' , len(set(corpora.split(' ')) ))

del corpora

model = Word2Vec( corpus, min_count = 5, vector_size = 300, window = 3, sg = 0, epochs = 5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1427/869447862.py in <cell line: 0>()
# ----> 1 import gensim.downloader as api
#       2 from gensim.models import Word2Vec
#       3
#       4 # print(api.info()['corpora'])
#       5
#
# ModuleNotFoundError: No module named 'gensim'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model.wv.most_similar('first', topn = 10)

# %%
len(model.wv.index_to_key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3639/683423864.py in <cell line: 0>()
# ----> 1 len(model.wv.index_to_key)
#
# NameError: name 'model' is not defined
