# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/NLP/blob/main/59Tag%20Recommendation%20with%20FastText%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AshishJangra27/datasets

# %%
import pandas as pd

df = pd.read_csv('/content/datasets/Myntra Products/products.csv')
df.head(2)

# %%
df['features'] = df['product_name'] + ' ' +  df['product_tag'] + ' ' + df['brand_tag']
df['tags'] = ',' + df['tags']
df['label'] = [' __label__'.join(tag.split(',')).strip().lower() for tag in df['tags']]

df.head(2)

# %%
data = [i[-1] + ' ' + i[-2] for i in df.values]

fd = open('data.txt','w')
for i in data:
  fd.write(i)
  fd.write('\n')

fd.close()


import fasttext

model = fasttext.train_supervised(input = 'data.txt')


import numpy as np

for i in range(50):
  txt = df['features'][np.random.randint(len(df['features']))]
  print(txt)
  print(model.predict(txt.lower(), k = 5)[0])
  print('-'*30)
