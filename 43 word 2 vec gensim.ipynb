# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/NLP/blob/main/43%20word%202%20vec%20gensim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim
from gensim.models import Word2Vec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 63.8 MB/s eta 0:00:00
# ...

# %%
sentences = [['human', 'interface', 'computer'],
            ['survey', 'user', 'computer', 'system', 'response', 'time'],
            ['eps', 'user', 'interface', 'system'],
            ['system', 'human', 'system', 'eps'],
            ['user', 'response', 'time'],
            ['trees'],
            ['graph', 'trees'],
            ['graph', 'minors', 'trees'],
            ['graph', 'minors', 'survey']]

# %%
model = Word2Vec(sentences = sentences, min_count = 1, vector_size = 10)

# %%
print(model.wv['trees'])
# Out:
# [ 0.07311766  0.05070262  0.06757693  0.00762866  0.06350891 -0.03405366
#  -0.00946401  0.05768573 -0.07521638 -0.03936104]

# %%
model.wv.similarity('human','computer')
# Out:
# np.float32(-0.22643761)

# %%
model.wv.most_similar('computer', topn = 10)
# Out:
# [('eps', 0.2914133667945862),
#  ('trees', 0.05541810393333435),
#  ('minors', 0.042647670954465866),
#  ('survey', -0.02176341600716114),
#  ('interface', -0.15233567357063293),
#  ('time', -0.19863171875476837),
#  ('response', -0.2179230898618698),
#  ('human', -0.22643756866455078),
#  ('user', -0.23134341835975647),
#  ('graph', -0.5145737528800964)]
